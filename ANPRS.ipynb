# %%
# %pip show tensorflow
# %matplotlib inline
# Out:
# WARNING: Package(s) not found: tensorflow
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %pip install opencv-python
import cv2
import glob
import time
import tqdm
import os
# import tensorflow as tf
# from torchvision.utils import make_grid
# from torchvision.display import Image


import warnings
warnings.filterwarnings('ignore')

# %%
# Check for GPU
import torch

torch.cuda.is_available()
device = torch.device("cuda")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Loading images

# %%
IMAGE_DIR = "./Image and Video data/images"

# count images in the folder
count = 0
for i in os.listdir(IMAGE_DIR):
    if os.path.isfile(os.path.join(IMAGE_DIR, i)):
        count+=1
print(f"Total images: {count}")
# Out:
# Total images: 10796

# %%
# lets plot the first few images
k = 0 #Number of images to be plotted
for k, i in enumerate(os.listdir(IMAGE_DIR)):
    img = mpimg.imread(os.path.join(IMAGE_DIR, i))
    print(i)
    plt.imshow(img)
    plt.axis("off")
    k+=1
    if k == 10:
        break
# Out:
# 00009e5b390986a0_jpg.rf.5516624c9b4aaf25de79e52e92103263.jpg
# 000228608388803f_jpg.rf.00d0afce70bbc182f81d011a9d944eef.jpg
# 0002a5b67e5f0909_jpg.rf.04522e99b36365b46ca5bb9fcb00b1ee.jpg
# 00043e7c5c4c025a_jpg.rf.72dcdbc719f748fe9e4abe1cb7e50d4f.jpg
# 0005ea10e0e14db1_jpg.rf.6c8dd006bdd331512463c6184c21916e.jpg
# 0006dc0977056410_jpg.rf.7efafb7ef877c26df0d27199678d21aa.jpg
# 00071c51c8e92a68_jpg.rf.ef1859119be5a9dea9157960aec63d45.jpg
# 00072b81abc72d21_jpg.rf.91fa4d5efe1736cb2573227b9506162f.jpg
# 0007870724402b51_jpg.rf.0ffc0ef8d5de2b4bb9614d2f7551e531.jpg
# 000812dcf304a8e7_jpg.rf.af92008529b97469372bc2c43fb087cf.jpg

# %%
img = mpimg.imread(os.path.join(IMAGE_DIR, '00009e5b390986a0_jpg.rf.5516624c9b4aaf25de79e52e92103263.jpg'))
plt.imshow(img)
